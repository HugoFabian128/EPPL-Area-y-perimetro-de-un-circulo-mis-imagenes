# %% [markdown]
# <a href="https://colab.research.google.com/github/HugoFabian128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/blob/main/El_profe_Circulo_Hugo_Fabian_0040.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Hugo Fabian Anbtonio NL = 15 Fecha 25/Mar/2026 ❤
# ---
# # Calcular area y perimetro de un circulo
# ---
# ![Captura circulo.PNG](https://raw.githubusercontent.com/HugoFabian128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/circulo_area_perimetro.PNG)
# ---
# ### formulas para calcular area
# $A=\pi*r^2$
# ---
# $P=2*\pi*r$
# ---
# ## Datos de entrada
# $r$ ?
# ---
# ## Diagrama de flujo en lucidChart
# ![Captura circulo.PNG](https://raw.githubusercontent.com/HugoFabian128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/DF%20Area%20perimetro%20circulo.png)

# %%
# Calcular area y perimetro de un circulo
# Variables A, P, r
# Formulas A = pi * r^2 y P = 2 * pi * r
# Capturar el valor de r
import math
print("Calcular area y perimetro de un circulo")
r = float(input("Ingrese el valor de r: "))
A = math.pi*r**2
P = 2*math.pi*r
print("El area del circulo es: ", A)
print("El perimetro del circulo es: ", P)
print("Hugo Fabian NL = 15")
# Out:
# Calcular area y perimetro de un circulo
# Ingrese el valor de r: 67
# El area del circulo es:  14102.609421964582
# El perimetro del circulo es:  420.97341558103227
# Hugo Fabian NL = 15

# %% [markdown]
# # Relacion entre codigo y DF en Tldraw
# ![Logo de Markdown](https://raw.githubusercontent.com/HugoFabian128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/tlderaw%20DF%20%20y%20codigo.png)
